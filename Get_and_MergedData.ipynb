# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Earthquake_Dataset1.csv')
df1
# Out:
#                           time  latitude  longitude    depth  mag magType  \
# 0     2023-10-20T23:00:21.109Z   14.3667   -93.4221   10.000  4.9     mww
# 1     2023-10-20T21:21:24.042Z  -19.1188  -173.3136   10.000  4.5      mb
# 2     2023-10-20T19:51:55.439Z    0.7788   125.2063   51.393  5.2      mb
# 3     2023-10-20T19:34:02.111Z   -5.4912   150.2567  124.504  4.9      mb
# 4     2023-10-20T19:16:09.952Z   30.9618   141.4852   35.000  4.5      mb
# ...                        ...       ...        ...      ...  ...     ...
# 1094  2023-08-20T15:28:22.458Z   39.7778    77.6881   10.000  4.7      mb
# 1095  2023-08-20T13:23:05.475Z   -8.5693   159.3791   80.366  4.9      mb
# 1096  2023-08-20T07:42:43.181Z   20.6364    94.4043   61.128  4.7      mb
# 1097  2023-08-20T01:48:54.796Z   51.6270  -167.3235   10.000  5.2     mww
# 1098  2023-08-20T01:30:38.563Z  -15.2393  -172.7011   10.000  4.5      mb
#
#         nst    gap   dmin   rms  ...                   updated  \
# 0     100.0   91.0  2.272  0.57  ...  2023-10-27T04:49:42.304Z
# 1      19.0  173.0  2.705  0.51  ...  2023-10-27T05:19:03.040Z
# 2     194.0   44.0  2.160  0.92  ...  2023-10-24T16:55:33.028Z
# 3      42.0   82.0  2.298  0.76  ...  2023-10-20T19:48:04.040Z
# 4      33.0  128.0  2.574  1.17  ...  2023-10-20T19:36:35.040Z
# ...     ...    ...    ...   ...  ...                       ...
# 1094   69.0   97.0  2.025  0.62  ...  2023-09-17T15:13:59.040Z
# 1095   53.0   48.0  1.030  0.66  ...  2023-09-17T14:49:14.750Z
# 1096  125.0   56.0  4.797  0.54  ...  2023-09-14T12:45:59.040Z
# 1097  133.0  117.0  1.643  0.99  ...  2023-10-22T01:59:03.149Z
# 1098   20.0   74.0  1.594  1.34  ...  2023-09-17T00:51:16.040Z
#
#                                       place        type horizontalError  \
# 0       114 km WSW of Puerto Madero, Mexico  earthquake            5.62
# 1                                     Tonga  earthquake           14.23
# 2           66 km SSE of Tondano, Indonesia  earthquake            6.19
# 3      14 km ENE of Kimbe, Papua New Guinea  earthquake           10.89
# 4                                       NaN  earthquake           11.21
# ...                                     ...         ...             ...
# 1094               southern Xinjiang, China  earthquake            6.48
# 1095    52 km SSW of Buala, Solomon Islands  earthquake            8.91
# 1096             51 km SW of Chauk, Myanmar  earthquake            7.54
# 1097  Fox Islands, Aleutian Islands, Alaska  earthquake            6.10
# 1098             141 km NE of Hihifo, Tonga  earthquake            7.82
#
#      depthError  magError  magNst    status  locationSource magSource
# 0         1.757     0.058    29.0  reviewed              us        us
# 1         1.972     0.131    17.0  reviewed              us        us
# 2         4.880     0.038   238.0  reviewed              us        us
# 3         7.699     0.102    30.0  reviewed              us        us
# 4         1.909     0.125    19.0  reviewed              us        us
# ...         ...       ...     ...       ...             ...       ...
# 1094      1.882     0.055   101.0  reviewed              us        us
# 1095      5.055     0.049   134.0  reviewed              us        us
# 1096      4.901     0.051   117.0  reviewed              us        us
# 1097      1.822     0.040    59.0  reviewed              us        us
# 1098      1.842     0.171    12.0  reviewed              us        us
#
# [1099 rows x 22 columns]

# %%
df2 = pd.read_csv('Earthquake_Dataset2.csv')
df2
# Out:
#                             date  latitude  longitude  depth  magnitude  \
# 0       1985-01-01T11:01:00+0000   47.0000   -66.6000   5.00        1.9
# 1       1985-01-01T12:34:37+0000   78.8000  -102.3300  18.00        3.2
# 2       1985-01-02T00:13:06+0000   48.8800  -122.9940  22.50        1.2
# 3       1985-01-02T00:56:59+0000   50.0220  -121.5540  18.00        1.0
# 4       1985-01-02T05:03:03+0000   49.4590   -66.7520  18.00        1.8
# ...                          ...       ...        ...    ...        ...
# 101360  2019-12-31T18:37:24+0000   50.4878  -121.0354  14.00        1.8
# 101361  2019-12-31T22:18:53+0000   48.2504   -78.4490   0.00        2.4
# 101362  2019-12-31T23:11:07+0000   50.5262  -121.0061  10.45        2.0
# 101363  2019-12-31T23:53:23+0000   45.0834   -74.7183  18.00        1.9
# 101364  2019-12-31T23:54:02+0000   47.4919   -70.4124   3.79        1.3
#
#        magnitude type                         place Unnamed: 7 Unnamed: 8
# 0                  MN    61 km E  from Plaster Rock         NB        NaN
# 1                  MN        26 km E  from Isachsen         NU        NaN
# 2                  ML      21 km SW from White Rock         BC        NaN
# 3                  ML         56 km W  from Merritt         BC        NaN
# 4                  MN        40 km N  from Cap-Chat         QC        NaN
# ...               ...                           ...        ...        ...
# 101360             ML      31 km SE of Ashcroft, BC        NaN        NaN
# 101361             MN       Blast, Laronde Mine, QC        NaN        NaN
# 101362             ML      29 km SE of Ashcroft, BC        NaN        NaN
# 101363             MN      6 km N from Cornwall, ON        NaN        NaN
# 101364             MN  CHARLEVOIX SEISMIC ZONE, QC.        NaN        NaN
#
# [101365 rows x 9 columns]

# %%
# check column
df1.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
# check column
df2.columns
# Out:
# Index(['date', 'latitude', 'longitude', 'depth', 'magnitude', 'magnitude type',
#        'place', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
# ลบ column ที่ไม่จำเป็นออก
df1_E = df1.drop(columns=['magType', 'rms', 'net', 'id', 'updated', 'type',
                        'horizontalError', 'depthError', 'magError', 'magNst', 'status','locationSource', 'magSource'])
df1_E
# Out:
#                           time  latitude  longitude    depth  mag    nst  \
# 0     2023-10-20T23:00:21.109Z   14.3667   -93.4221   10.000  4.9  100.0
# 1     2023-10-20T21:21:24.042Z  -19.1188  -173.3136   10.000  4.5   19.0
# 2     2023-10-20T19:51:55.439Z    0.7788   125.2063   51.393  5.2  194.0
# 3     2023-10-20T19:34:02.111Z   -5.4912   150.2567  124.504  4.9   42.0
# 4     2023-10-20T19:16:09.952Z   30.9618   141.4852   35.000  4.5   33.0
# ...                        ...       ...        ...      ...  ...    ...
# 1094  2023-08-20T15:28:22.458Z   39.7778    77.6881   10.000  4.7   69.0
# 1095  2023-08-20T13:23:05.475Z   -8.5693   159.3791   80.366  4.9   53.0
# 1096  2023-08-20T07:42:43.181Z   20.6364    94.4043   61.128  4.7  125.0
# 1097  2023-08-20T01:48:54.796Z   51.6270  -167.3235   10.000  5.2  133.0
# 1098  2023-08-20T01:30:38.563Z  -15.2393  -172.7011   10.000  4.5   20.0
#
#         gap   dmin                                  place
# 0      91.0  2.272    114 km WSW of Puerto Madero, Mexico
# 1     173.0  2.705                                  Tonga
# 2      44.0  2.160        66 km SSE of Tondano, Indonesia
# 3      82.0  2.298   14 km ENE of Kimbe, Papua New Guinea
# 4     128.0  2.574                                    NaN
# ...     ...    ...                                    ...
# 1094   97.0  2.025               southern Xinjiang, China
# 1095   48.0  1.030    52 km SSW of Buala, Solomon Islands
# 1096   56.0  4.797             51 km SW of Chauk, Myanmar
# 1097  117.0  1.643  Fox Islands, Aleutian Islands, Alaska
# 1098   74.0  1.594             141 km NE of Hihifo, Tonga
#
# [1099 rows x 9 columns]

# %%
# ลบ column ที่ไม่จำเป็นออก
df2_E = df2.drop(columns=['magnitude type', 'Unnamed: 7', 'Unnamed: 8'])
df2_E
# Out:
#                             date  latitude  longitude  depth  magnitude  \
# 0       1985-01-01T11:01:00+0000   47.0000   -66.6000   5.00        1.9
# 1       1985-01-01T12:34:37+0000   78.8000  -102.3300  18.00        3.2
# 2       1985-01-02T00:13:06+0000   48.8800  -122.9940  22.50        1.2
# 3       1985-01-02T00:56:59+0000   50.0220  -121.5540  18.00        1.0
# 4       1985-01-02T05:03:03+0000   49.4590   -66.7520  18.00        1.8
# ...                          ...       ...        ...    ...        ...
# 101360  2019-12-31T18:37:24+0000   50.4878  -121.0354  14.00        1.8
# 101361  2019-12-31T22:18:53+0000   48.2504   -78.4490   0.00        2.4
# 101362  2019-12-31T23:11:07+0000   50.5262  -121.0061  10.45        2.0
# 101363  2019-12-31T23:53:23+0000   45.0834   -74.7183  18.00        1.9
# 101364  2019-12-31T23:54:02+0000   47.4919   -70.4124   3.79        1.3
#
#                                place
# 0         61 km E  from Plaster Rock
# 1             26 km E  from Isachsen
# 2           21 km SW from White Rock
# 3              56 km W  from Merritt
# 4             40 km N  from Cap-Chat
# ...                              ...
# 101360      31 km SE of Ashcroft, BC
# 101361       Blast, Laronde Mine, QC
# 101362      29 km SE of Ashcroft, BC
# 101363      6 km N from Cornwall, ON
# 101364  CHARLEVOIX SEISMIC ZONE, QC.
#
# [101365 rows x 6 columns]

# %%
# แก้ไขชื่อ columns ของตาราง data
df1_E.columns = ['date', 'latitude', 'longitude', 'depth', 'magnitude', 'nst','gap', 'dmin', 'place']
df1_E
# Out:
#                           date  latitude  longitude    depth  magnitude  \
# 0     2023-10-20T23:00:21.109Z   14.3667   -93.4221   10.000        4.9
# 1     2023-10-20T21:21:24.042Z  -19.1188  -173.3136   10.000        4.5
# 2     2023-10-20T19:51:55.439Z    0.7788   125.2063   51.393        5.2
# 3     2023-10-20T19:34:02.111Z   -5.4912   150.2567  124.504        4.9
# 4     2023-10-20T19:16:09.952Z   30.9618   141.4852   35.000        4.5
# ...                        ...       ...        ...      ...        ...
# 1094  2023-08-20T15:28:22.458Z   39.7778    77.6881   10.000        4.7
# 1095  2023-08-20T13:23:05.475Z   -8.5693   159.3791   80.366        4.9
# 1096  2023-08-20T07:42:43.181Z   20.6364    94.4043   61.128        4.7
# 1097  2023-08-20T01:48:54.796Z   51.6270  -167.3235   10.000        5.2
# 1098  2023-08-20T01:30:38.563Z  -15.2393  -172.7011   10.000        4.5
#
#         nst    gap   dmin                                  place
# 0     100.0   91.0  2.272    114 km WSW of Puerto Madero, Mexico
# 1      19.0  173.0  2.705                                  Tonga
# 2     194.0   44.0  2.160        66 km SSE of Tondano, Indonesia
# 3      42.0   82.0  2.298   14 km ENE of Kimbe, Papua New Guinea
# 4      33.0  128.0  2.574                                    NaN
# ...     ...    ...    ...                                    ...
# 1094   69.0   97.0  2.025               southern Xinjiang, China
# 1095   53.0   48.0  1.030    52 km SSW of Buala, Solomon Islands
# 1096  125.0   56.0  4.797             51 km SW of Chauk, Myanmar
# 1097  133.0  117.0  1.643  Fox Islands, Aleutian Islands, Alaska
# 1098   20.0   74.0  1.594             141 km NE of Hihifo, Tonga
#
# [1099 rows x 9 columns]

# %%
merged_df = pd.concat([df1_E, df2_E], ignore_index=True)
merged_df
# Out:
#                             date  latitude  longitude    depth  magnitude  \
# 0       2023-10-20T23:00:21.109Z   14.3667   -93.4221   10.000        4.9
# 1       2023-10-20T21:21:24.042Z  -19.1188  -173.3136   10.000        4.5
# 2       2023-10-20T19:51:55.439Z    0.7788   125.2063   51.393        5.2
# 3       2023-10-20T19:34:02.111Z   -5.4912   150.2567  124.504        4.9
# 4       2023-10-20T19:16:09.952Z   30.9618   141.4852   35.000        4.5
# ...                          ...       ...        ...      ...        ...
# 102459  2019-12-31T18:37:24+0000   50.4878  -121.0354   14.000        1.8
# 102460  2019-12-31T22:18:53+0000   48.2504   -78.4490    0.000        2.4
# 102461  2019-12-31T23:11:07+0000   50.5262  -121.0061   10.450        2.0
# 102462  2019-12-31T23:53:23+0000   45.0834   -74.7183   18.000        1.9
# 102463  2019-12-31T23:54:02+0000   47.4919   -70.4124    3.790        1.3
#
#           nst    gap   dmin                                 place
# 0       100.0   91.0  2.272   114 km WSW of Puerto Madero, Mexico
# 1        19.0  173.0  2.705                                 Tonga
# 2       194.0   44.0  2.160       66 km SSE of Tondano, Indonesia
# 3        42.0   82.0  2.298  14 km ENE of Kimbe, Papua New Guinea
# 4        33.0  128.0  2.574                                   NaN
# ...       ...    ...    ...                                   ...
# 102459    NaN    NaN    NaN              31 km SE of Ashcroft, BC
# 102460    NaN    NaN    NaN               Blast, Laronde Mine, QC
# 102461    NaN    NaN    NaN              29 km SE of Ashcroft, BC
# 102462    NaN    NaN    NaN              6 km N from Cornwall, ON
# 102463    NaN    NaN    NaN          CHARLEVOIX SEISMIC ZONE, QC.
#
# [102464 rows x 9 columns]

# %%
merged_df.to_csv('Merged_EarthQuake_data.csv', index=False)
